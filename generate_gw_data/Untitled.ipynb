# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load train and test CSV files
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
labels = pd.read_csv('labels.csv')

# Print the contents of train dataframe
print("Train Data:")
print(train_df.head())  # Display the first few rows of the train dataframe
print()

# Print the contents of test dataframe
print("Test Data:")
print(test_df.head())  # Display the first few rows of the test dataframe
print()

# Print the contents of labels dataframe
print("Labels Data:")
print(labels.head())  # Display the first few rows of the labels dataframe
print()

# Plot the first five test samples
for i in range(5):
    plt.figure()
    plt.plot(test_df.iloc[i])  # Plot the time series data for the i-th test sample
    plt.title(f"Test Sample {i+1} - Label: {labels.iloc[i, 0]}")  # Assuming labels are in the first column
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.show()
# Out:
# Train Data:
#    -1.9537938316438434e+21  7.261213438548969e+20  1.545161889310351e+21  \
# 0            -1.560709e+20          -4.825364e+20           6.764577e+20
# 1            -1.092642e+21           6.900505e+20          -1.047684e+21
# 2            -1.038623e+21          -3.402886e+20          -8.273990e+20
# 3             1.042007e+20          -9.526085e+18           1.991742e+18
# 4            -1.758975e+20          -6.164220e+20          -8.323785e+20
#
#    -8.219702366533061e+17  -7.953251566058267e+20  -2.365648981135503e+20  \
# 0            7.078276e+20           -8.994093e+20            8.563110e+20
# 1           -6.154732e+20           -7.303509e+20            2.963418e+20
# 2            3.334259e+19           -2.950989e+20            8.343410e+19
# 3            1.909076e+18           -1.677865e+20            1.696647e+21
# 4            1.518586e+21           -5.118434e+20            2.143504e+21
#
# ...

# %%
print(test_df.shape)
print(train_df.shape)
print(labels.shape)
# Out:
# (4095, 300)
# (4095, 300)
# (299, 1)

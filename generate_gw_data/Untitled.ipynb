# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load train and test CSV files
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
labels = pd.read_csv('labels.csv')

# Print the contents of train dataframe
print("Train Data:")
print(train_df.head())  # Display the first few rows of the train dataframe
print()

# Print the contents of test dataframe
print("Test Data:")
print(test_df.head())  # Display the first few rows of the test dataframe
print()

# Print the contents of labels dataframe
print("Labels Data:")
print(labels.head())  # Display the first few rows of the labels dataframe
print()

# Plot the first five test samples
for i in range(5):
    plt.figure()
    plt.plot(test_df.iloc[i])  # Plot the time series data for the i-th test sample
    plt.title(f"Test Sample {i+1} - Label: {labels.iloc[i, 0]}")  # Assuming labels are in the first column
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.show()
# Out:
# Train Data:
#    9.272428101235147e+20  2.1437184219209794e+20  6.805996295233037e+20  \
# 0          -1.412405e+20           -1.007202e+21           1.224823e+21
# 1          -5.732406e+20            3.406539e+21          -6.665106e+20
# 2           2.461299e+19            9.703751e+20           1.175463e+21
# 3           1.056239e+21           -8.284339e+20          -4.653303e+20
# 4           4.247041e+20           -2.839915e+20          -8.912941e+20
#
#    1.0996614787348308e+21  -9.330995310462321e+20  -1.0616347226379313e+21  \
# 0           -6.773735e+20            1.939591e+20             7.282332e+20
# 1           -9.066124e+20           -1.535187e+21             8.004228e+19
# 2            6.839847e+20           -5.566468e+20            -9.826302e+20
# 3            1.194148e+21            1.101500e+21            -8.656831e+19
# 4           -1.216066e+21            1.228760e+21             6.338524e+20
#
#    8.867448574897945e+20  -1.710890537101289e+20  -2.641594417546398e+21  \
# 0          -3.877623e+20           -3.465294e+20            1.994384e+21
# 1          -3.220284e+20            1.797249e+21            7.660631e+20
# 2          -7.391504e+20            6.891919e+20           -1.919927e+21
# 3           5.872271e+20            1.166767e+20           -2.358175e+21
# 4           1.506404e+20           -1.510346e+21           -2.766128e+20
#
#    1.0759818457168004e+21  ...  -6.262151664868456e+20  \
# 0            1.036081e+21  ...           -1.663674e+21
# 1           -4.309790e+20  ...           -7.850992e+20
# 2           -2.428436e+21  ...            7.694237e+20
# 3            1.289648e+21  ...           -6.986204e+18
# 4           -1.016886e+21  ...            3.327663e+20
#
#    -4.452652733577871e+20  -1.5780290491494413e+20  9.594286369604844e+20  \
# 0           -3.975644e+20             1.452510e+21           5.573184e+20
# 1            1.843275e+21            -2.863123e+20           1.293877e+20
# 2           -8.081659e+20            -5.386232e+20           1.075907e+21
# 3           -1.051464e+21            -3.802989e+20           1.390236e+20
# 4            9.623305e+20            -4.863372e+19          -9.249183e+20
#
#    -3.21904088510842e+20  5.338756135122268e+20  3.586681401867893e+20  \
# 0           3.316523e+20           1.503405e+21           2.022912e+21
# 1           1.582018e+21          -2.569086e+21           1.418575e+21
# 2           4.826646e+20           1.563167e+21           4.793959e+20
# 3          -2.401449e+20          -7.369821e+19           1.072245e+20
# 4           4.163350e+20           6.160881e+20          -4.954523e+20
#
#    2.5937854373125092e+20  2.7360204604275614e+21  9.789958838754622e+19
# 0            1.712201e+21           -4.658289e+19          -1.095986e+21
# 1           -1.595903e+21           -9.020755e+19           2.104077e+21
# 2            7.833754e+20           -1.070075e+21          -6.196183e+20
# 3           -8.698763e+20           -1.255878e+21          -2.835177e+20
# 4            1.658029e+21            3.167824e+20           1.531084e+21
#
# [5 rows x 4096 columns]
#
# Test Data:
#    3.207623803430255e+20  7.1410706314432725e+19  -7.987564018016209e+20  \
# 0           1.404156e+21            5.853461e+20           -2.965530e+21
# 1           9.418597e+20            3.832916e+20            3.202665e+19
# 2          -1.189189e+21           -3.407009e+20           -1.624666e+21
# 3           4.818719e+20           -3.753458e+20           -9.980584e+19
# 4          -1.278209e+21           -1.160981e+21           -5.876613e+20
#
#    -9.366058995699471e+20  1.1799584347423509e+21  8.871719748994624e+20  \
# 0            3.664239e+20           -3.739118e+20          -9.939485e+20
# 1           -9.498552e+20           -2.787209e+20           1.463529e+20
# 2           -2.201452e+19            8.193067e+20           1.252059e+20
# 3            6.160559e+20           -3.093065e+20           7.572349e+19
# 4           -2.229569e+21           -6.415999e+20          -1.433138e+20
#
#    6.558390073077902e+20  5.345680208744307e+20  -5.6230960539890555e+20  \
# 0          -3.397466e+19           1.353892e+20             1.883375e+21
# 1           1.550102e+19          -4.191264e+18            -7.814053e+20
# 2           1.942348e+21           1.743324e+21             4.994522e+20
# 3           6.364381e+19          -4.051747e+20             6.367021e+20
# 4          -3.893469e+20          -1.729434e+21            -1.346325e+21
#
#    9.012126737817985e+20  ...  6.79026290807707e+20  4.396696336460413e+20  \
# 0          -1.683046e+21  ...         -1.657618e+21           3.638308e+20
# 1          -9.642408e+20  ...         -5.587497e+20           8.741809e+20
# 2           3.452452e+20  ...          1.482896e+21          -5.722438e+20
# 3           1.114552e+20  ...          1.584856e+21           6.785172e+20
# 4          -4.051435e+20  ...         -8.825428e+20          -2.432423e+20
#
#    4.1920902129644097e+20  1.233867587359728e+20  -8.260296578218244e+20  \
# 0           -6.070650e+20          -1.171113e+21            1.175889e+21
# 1           -2.683189e+20           1.008375e+20            8.020026e+20
# 2            3.213803e+20           7.821988e+19            2.518104e+20
# 3           -5.986148e+20           3.378593e+20            1.911246e+21
# 4           -1.165435e+21           3.781207e+20           -7.776495e+20
#
#    1.6364167221624593e+20  4.489768597038711e+20  1.239124375116366e+20  \
# 0           -6.471030e+20           5.138044e+20           3.251665e+20
# 1            5.986752e+20          -1.343654e+21           4.845454e+20
# 2           -6.826830e+19          -1.515287e+21          -1.511195e+21
# 3            8.517056e+20          -1.977276e+21           4.353043e+20
# 4           -5.188325e+19           1.401883e+21          -3.065067e+20
#
#    -1.3115560967183144e+21  2.705582217296991e+20
# 0             1.215484e+21           1.253731e+20
# 1            -6.585726e+20           2.679947e+20
# 2             3.434116e+21          -1.684649e+21
# 3             5.575050e+20          -2.275699e+20
# 4             1.245059e+21           1.936351e+21
#
# [5 rows x 4096 columns]
#
# Labels Data:
#    1.0
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  0.0
# KeyboardInterrupt

# %%
print(test_df.shape)
print(train_df.shape)
print(labels.shape)
# Out:
# (4095, 300)
# (4095, 300)
# (299, 1)
